# %% [markdown]
# # Project 1: E-Commerce Intelligence - Step 3: Demand & Price Forecasting
#
# This notebook trains regression models to forecast retail product demand and optimization of pricing schemes.
#
# ## Blueprint Actions Covered
# * **Algorithms**: Simple and Multiple Linear Regression, regularized models (Ridge, Lasso, Elastic Net) to handle multicollinearity, Polynomial Regression, and Support Vector Regressors (SVR).
# * **Metrics**: Performance evaluation utilizing financial metrics (MAE, MSE, RMSE, and $R^2$).

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.preprocessing import PolynomialFeatures
from sklearn.svm import SVR
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
